# %% [markdown]
# ## Importação das Bibliotecas

# %%
# Importar as bibliotecas necessárias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import urllib.request
import zipfile
import os

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Comando para baixar os dados (descomente para executar)
##urllib.request.urlretrieve("https://files.grouplens.org/datasets/movielens/ml-1m.zip", "ml-1m.zip")

# Descompactar o arquivo
with zipfile.ZipFile("ml-1m.zip", 'r') as zip_ref:
    zip_ref.extractall("ml-1m")

# %%
# Carregar os dados em dataframes
ratings = pd.read_csv('ml-1m/ml-1m/ratings.dat', sep='::', header=None, engine='python', names=['user_id', 'movie_id', 'rating', 'timestamp'], encoding='latin1')
movies = pd.read_csv('ml-1m/ml-1m/movies.dat', sep='::', header=None, engine='python', names=['movie_id', 'title', 'genres'], encoding='latin1')
users = pd.read_csv('ml-1m/ml-1m/users.dat', sep='::', header=None, engine='python', names=['user_id', 'gender', 'age', 'occupation', 'zip_code'], encoding='latin1')

# %%
users.head()
# Out:
#    user_id gender  age  occupation zip_code
# 0        1      F    1          10    48067
# 1        2      M   56          16    70072
# 2        3      M   25          15    55117
# 3        4      M   45           7    02460
# 4        5      M   25          20    55455

# %%
ratings.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
movies.head()
# Out:
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %% [markdown]
# ## Análise Exploratória dos Dados
# Nesta seção, exploraremos os dados para entender sua estrutura e obter insights iniciais.

# %%
# Informações básicas
num_users = ratings['user_id'].nunique()
num_movies = ratings['movie_id'].nunique()
num_ratings = ratings.shape[0]

print(f'Número de usuários: {num_users}')
print(f'Número de filmes: {num_movies}')
print(f'Número de avaliações: {num_ratings}')

# Distribuição das avaliações
plt.figure(figsize=(10, 6))
sns.countplot(x='rating', data=ratings, palette="viridis")
plt.title('Distribuição das Avaliações')
plt.xlabel('Avaliação')
plt.ylabel('Contagem')
plt.show()
# Out:
# Número de usuários: 6040
# Número de filmes: 3706
# Número de avaliações: 1000209
# /tmp/ipykernel_1184/3946388797.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='rating', data=ratings, palette="viridis")

# %%
# Separar gêneros
genres = movies['genres'].str.split('|', expand=True).stack().reset_index(level=1, drop=True)
genres.name = 'genre'
movies_genres = movies[['movie_id', 'title']].join(genres)

# Distribuição dos gêneros
plt.figure(figsize=(14, 7))
sns.countplot(y=genres, order=genres.value_counts().index, palette="viridis")
plt.title('Distribuição dos Gêneros de Filmes')
plt.xlabel('Contagem')
plt.ylabel('Gênero')
plt.show()

# Filmes por ano
movies['year'] = movies['title'].str.extract(r'\((\d{4})\)')
movies['year'] = pd.to_numeric(movies['year'], errors='coerce')

plt.figure(figsize=(14, 7))
movies['year'].dropna().astype(int).plot(kind='hist', bins=30, color='purple', edgecolor='black')
plt.title('Distribuição dos Filmes por Ano')
plt.xlabel('Ano')
plt.ylabel('Contagem')
plt.show()
# Out:
# /tmp/ipykernel_1184/3726771713.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=genres, order=genres.value_counts().index, palette="viridis")

# %% [markdown]
# ## Pré-processamento dos Dados
# Nesta seção, realizaremos o pré-processamento dos dados, incluindo a verificação de duplicatas, normalização e construção de matrizes de distância.

# %%
# Verificar duplicatas
print(f'Duplicatas nas avaliações: {ratings.duplicated().sum()}')
print(f'Duplicatas nos filmes: {movies.duplicated().sum()}')
print(f"Duplicated users: {users.duplicated().sum()}")

# Pivotar a matriz de avaliações para criar uma matriz de usuário-filme
user_movie_matrix = ratings.pivot(index='user_id', columns='movie_id', values='rating').fillna(0)
# Out:
# Duplicatas nas avaliações: 0
# Duplicatas nos filmes: 0
# Duplicated users: 0

# %%
# Selecionar um subconjunto dos dados para a matriz de correlação
subset_user_movie_matrix = user_movie_matrix.iloc[:, :100]  # Selecionar os 100 primeiros filmes

# Calcular a matriz de correlação para o subconjunto
corr_matrix = subset_user_movie_matrix.corr()

# Plotar a matriz de correlação
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, cmap='coolwarm', xticklabels=False, yticklabels=False)
plt.title('Matriz de Correlação dos 100 Primeiros Filmes')
plt.show()

# %%
# Normalização dos dados (apenas se necessário)
scaler = StandardScaler()
user_movie_matrix_normalized = scaler.fit_transform(user_movie_matrix)

user_movie_matrix_normalized = pd.DataFrame(user_movie_matrix_normalized, index=user_movie_matrix.index, columns=user_movie_matrix.columns)

user_movie_matrix_normalized.head()
# Out:
# movie_id      1         2         3         4         5         6     \
# user_id
# 1         1.758734 -0.344462 -0.274956 -0.159317 -0.214328 -0.415292
# 2        -0.701718 -0.344462 -0.274956 -0.159317 -0.214328 -0.415292
# 3        -0.701718 -0.344462 -0.274956 -0.159317 -0.214328 -0.415292
# 4        -0.701718 -0.344462 -0.274956 -0.159317 -0.214328 -0.415292
# 5        -0.701718 -0.344462 -0.274956 -0.159317 -0.214328  0.960662
#
# movie_id      7         8         9         10    ...     3943      3944  \
# user_id                                           ...
# 1        -0.274471 -0.101751 -0.121857 -0.400567  ... -0.11754 -0.032983
# 2        -0.274471 -0.101751 -0.121857 -0.400567  ... -0.11754 -0.032983
# 3        -0.274471 -0.101751 -0.121857 -0.400567  ... -0.11754 -0.032983
# 4        -0.274471 -0.101751 -0.121857 -0.400567  ... -0.11754 -0.032983
# 5        -0.274471 -0.101751 -0.121857 -0.400567  ... -0.11754 -0.032983
#
# movie_id      3945      3946      3947      3948      3949      3950  \
# user_id
# 1        -0.069767 -0.117019 -0.090777 -0.390685 -0.223267 -0.091368
# 2        -0.069767 -0.117019 -0.090777 -0.390685 -0.223267 -0.091368
# 3        -0.069767 -0.117019 -0.090777 -0.390685 -0.223267 -0.091368
# 4        -0.069767 -0.117019 -0.090777 -0.390685 -0.223267 -0.091368
# 5        -0.069767 -0.117019 -0.090777 -0.390685 -0.223267 -0.091368
#
# movie_id      3951      3952
# user_id
# 1        -0.078855 -0.253864
# 2        -0.078855 -0.253864
# 3        -0.078855 -0.253864
# 4        -0.078855 -0.253864
# 5        -0.078855 -0.253864
#
# [5 rows x 3706 columns]

# %% [markdown]
# ## Aplicação dos Algoritmos de Clusterização
# Nesta seção, aplicaremos diferentes algoritmos de clusterização, incluindo K-means, DBSCAN e Clustering Hierárquico.

# %%
# Aplicar K-means
kmeans = KMeans(n_clusters=7.5, random_state=42)
kmeans_clusters = kmeans.fit_predict(user_movie_matrix_normalized)

# Adicionar rótulos de cluster ao dataframe de usuários
users = pd.DataFrame(index=user_movie_matrix.index)
users['cluster_kmeans'] = kmeans_clusters

# Verificar a distribuição dos clusters K-means
plt.figure(figsize=(10, 6))
sns.countplot(x='cluster_kmeans', data=users, palette="viridis")
plt.title('Distribuição dos Clusters K-means')
plt.xlabel('Cluster')
plt.ylabel('Contagem')
plt.show()

# Silhouette Score para K-means
silhouette_kmeans = silhouette_score(user_movie_matrix_normalized, kmeans_clusters)
print(f'Silhouette Score para K-means: {silhouette_kmeans}')
# Out:
# /home/dudu/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /tmp/ipykernel_1184/756577006.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='cluster_kmeans', data=users, palette="viridis")
# Silhouette Score para K-means: 0.2782613152478831

# %%
# Aplicar DBSCAN com os melhores parâmetros
dbscan = DBSCAN(metric='cosine', eps=0.5, min_samples=5)
dbscan_clusters = dbscan.fit_predict(user_movie_matrix_normalized)

# Adicionar rótulos de cluster ao dataframe de usuários
users['cluster_dbscan'] = dbscan_clusters

# Verificar a distribuição dos clusters DBSCAN
plt.figure(figsize=(10, 6))
sns.countplot(x='cluster_dbscan', data=users, palette="viridis")
plt.title('Distribuição dos Clusters DBSCAN')
plt.xlabel('Cluster')
plt.ylabel('Contagem')
plt.show()

# Silhouette Score para DBSCAN
n_clusters_dbscan = len(set(dbscan_clusters)) - (1 if -1 in dbscan_clusters else 0)
if n_clusters_dbscan > 1:
    silhouette_dbscan = silhouette_score(user_movie_matrix_normalized, dbscan_clusters, metric='cosine')
    print(f'Silhouette Score para DBSCAN: {silhouette_dbscan}')
else:
    print('DBSCAN resultou em um único cluster ou todos os pontos como ruído.')
# Out:
# Silhouette Score para DBSCAN: -0.06653719808869239

# %%
# Aplicar Clustering Hierárquico
agg_clustering = AgglomerativeClustering(n_clusters=None, affinity='cosine', linkage='complete', distance_threshold=0.5)
agg_clusters = agg_clustering.fit_predict(user_movie_matrix_normalized)

# Adicionar rótulos de cluster ao dataframe de usuários
users['cluster_agg'] = agg_clusters

# Verificar a distribuição dos clusters hierárquicos
plt.figure(figsize=(10, 6))
sns.countplot(x='cluster_agg', data=users, palette="viridis")
plt.title('Distribuição dos Clusters Hierárquicos')
plt.xlabel('Cluster')
plt.ylabel('Contagem')
plt.show()

# Silhouette Score para Clustering Hierárquico
silhouette_agg = silhouette_score(user_movie_matrix_normalized, agg_clusters, metric='cosine')
print(f'Silhouette Score para Clustering Hierárquico: {silhouette_agg}')
# Out:
# /home/dudu/.local/lib/python3.8/site-packages/sklearn/cluster/_agglomerative.py:1006: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# /tmp/ipykernel_1184/2282409630.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='cluster_agg', data=users, palette="viridis")
# Silhouette Score para Clustering Hierárquico: 0.014294841460285097

# %%
print(len(set(agg_clusters)))
# Out:
# 5779

# %% [markdown]
# ## Análise da Variação do Número de Clusters
#
# Nesta seção, analisaremos como a variação do número de clusters afeta os resultados dos algoritmos de clusterização. Usaremos o método do cotovelo para K-means e a análise de Silhouette Score.

# %%
# Método do Cotovelo para K-means
sse = []
silhouette_scores = []
k_range = range(2, 21)

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(user_movie_matrix_normalized)
    sse.append(kmeans.inertia_)
    silhouette_scores.append(silhouette_score(user_movie_matrix_normalized, kmeans.labels_))

# Plotar o Método do Cotovelo
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
plt.plot(k_range, sse, marker='o')
plt.title('Método do Cotovelo para K-means')
plt.xlabel('Número de Clusters')
plt.ylabel('SSE (Inércia)')

# Plotar o Silhouette Score
plt.subplot(1, 2, 2)
plt.plot(k_range, silhouette_scores, marker='o')
plt.title('Silhouette Score para K-means')
plt.xlabel('Número de Clusters')
plt.ylabel('Silhouette Score')
plt.show()

# %% [markdown]
# ## Remoção de Outliers
#
# Para remover outliers, definiremos critérios baseados na densidade de pontos usando DBSCAN. Pontos identificados como ruído (-1) pelo DBSCAN serão considerados outliers.

# %%
# Remoção de outliers usando DBSCAN
dbscan = DBSCAN(metric='cosine', eps=0.5, min_samples=5)
dbscan_clusters = dbscan.fit_predict(user_movie_matrix_normalized)

# Identificar os índices dos outliers
outliers = user_movie_matrix_normalized[dbscan_clusters == -1].index
print(f'Número de outliers identificados: {len(outliers)}')

# Remover outliers dos dados
user_movie_matrix_no_outliers = user_movie_matrix_normalized.drop(outliers)
print(f'Número de usuários após remoção de outliers: {user_movie_matrix_no_outliers.shape[0]}')
# Out:
# Número de outliers identificados: 5597
# Número de usuários após remoção de outliers: 443

# %% [markdown]
# ## Redução de Dimensionalidade
#
# Aplicaremos a redução de dimensionalidade utilizando PCA (Principal Component Analysis) e SVD (Singular Value Decomposition) para analisar como essas técnicas afetam os resultados dos algoritmos de clusterização.

# %%
from sklearn.decomposition import PCA, TruncatedSVD

# Aplicar PCA
pca = PCA(n_components=2)
user_movie_matrix_pca = pca.fit_transform(user_movie_matrix_normalized)

# Aplicar a decomposição SVD
svd = TruncatedSVD(n_components=min(user_movie_matrix_normalized.shape)-1, random_state=42)
svd.fit(user_movie_matrix_normalized)

# Obter os valores singulares
singular_values = svd.singular_values_

# Plotar os valores singulares
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(singular_values) + 1), singular_values, marker='o', linestyle='--')
plt.title('Valores Singulares da Decomposição SVD')
plt.xlabel('Número do Valor Singular')
plt.ylabel('Valor Singular')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Interpretação dos Clusters
#
# Nesta seção, interpretaremos os clusters formados por cada algoritmo. Identificaremos clusters com base nos filmes que eles contêm, como filmes de ficção científica ou de terror.

# %%
# Carregar informações dos filmes (u.item)
movie_titles = {}
with open('ml-1m/ml-1m/movies.dat', encoding='ISO-8859-1') as f:
    for line in f:
        parts = line.strip().split('::')
        movie_id = int(parts[0])
        title = parts[1]
        movie_titles[movie_id] = title

print(f'Total de filmes carregados: {len(movie_titles)}')
# Out:
# Total de filmes carregados: 3883

# %%
# Função para exibir filmes em um cluster
def display_cluster_movies(cluster_labels, n_clusters, title):
    for cluster in range(n_clusters):
        print(f'\nCluster {cluster} ({title}):')
        cluster_indices = np.where(cluster_labels == cluster)[0]
        for index in cluster_indices[:10]:  # Mostrar os 10 primeiros usuários no cluster
            rated_movie_indices = np.where(user_movie_matrix.iloc[index, :] > 0)[0]
            rated_movies = [user_movie_matrix.columns[i] for i in rated_movie_indices]
            movie_titles_in_cluster = [movie_titles[movie_id] for movie_id in rated_movies[:10]]
            for movie_title in movie_titles_in_cluster:
                print(f"- {movie_title}")

# Interpretar clusters do K-means
n_clusters_kmeans = 7.5
kmeans = KMeans(n_clusters=n_clusters_kmeans, random_state=42)
kmeans_clusters = kmeans.fit_predict(user_movie_matrix_normalized)
display_cluster_movies(kmeans_clusters, n_clusters_kmeans, 'K-means')

# Interpretar clusters do Clustering Hierárquico
agg_clustering = AgglomerativeClustering(n_clusters=10, affinity='cosine', linkage='complete')
agg_clusters = agg_clustering.fit_predict(user_movie_matrix_normalized)
display_cluster_movies(agg_clusters, 10, 'Clustering Hierárquico')
# Out:
# Cluster 0 (K-means):
# - Get Shorty (1995)
# - Braveheart (1995)
# - Star Wars: Episode IV - A New Hope (1977)
# - Pushing Hands (1992)
# - Fugitive, The (1993)
# - In the Line of Fire (1993)
# - Ruby in Paradise (1993)
# - Terminator 2: Judgment Day (1991)
# - Godfather, The (1972)
# - African Queen, The (1951)
# - Get Shorty (1995)
# - Shanghai Triad (Yao a yao yao dao waipo qiao) (1995)
# - Twelve Monkeys (1995)
# - Dead Man Walking (1995)
# - Clueless (1995)
# - To Die For (1995)
# - Usual Suspects, The (1995)
# - Mighty Aphrodite (1995)
# - Taxi Driver (1976)
# - Flirting With Disaster (1996)
# - Grumpier Old Men (1995)
# - Wes Craven's New Nightmare (1994)
# - Rudy (1993)
# - Terminator 2: Judgment Day (1991)
# - Batman (1989)
# - Halloween: The Curse of Michael Myers (1995)
# - Grosse Fatigue (1994)
# - Sex, Lies, and Videotape (1989)
# - Shining, The (1980)
# - Zeus and Roxanne (1997)
# - Leaving Las Vegas (1995)
# - Usual Suspects, The (1995)
# - Nico Icon (1995)
# - Heidi Fleiss: Hollywood Madam (1995)
# - Taxi Driver (1976)
# - Belle de jour (1967)
# - Devil in a Blue Dress (1995)
# - Heavenly Creatures (1994)
# - Pulp Fiction (1994)
# - Schindler's List (1993)
#
# Cluster 1 (K-means):
# - Toy Story (1995)
# - Jumanji (1995)
# - Heat (1995)
# - American President, The (1995)
# - Casino (1995)
# - Get Shorty (1995)
# - City of Lost Children, The (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Clueless (1995)
# - Casino (1995)
# - Sense and Sensibility (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Dead Man Walking (1995)
# - Seven (Se7en) (1995)
# - Usual Suspects, The (1995)
# - Braveheart (1995)
# - Taxi Driver (1976)
# - Apollo 13 (1995)
# - Sabrina (1995)
# - Sense and Sensibility (1995)
# - Persuasion (1995)
# - Dead Man Walking (1995)
# - Clueless (1995)
# - Postino, Il (The Postman) (1994)
# - Chungking Express (1994)
# - Belle de jour (1967)
# - Beyond Rangoon (1995)
# - Pulp Fiction (1994)
# - Toy Story (1995)
# - Grumpier Old Men (1995)
# - Sabrina (1995)
# - American President, The (1995)
# - Leaving Las Vegas (1995)
# - Babe (1995)
# - Carrington (1995)
# - Clueless (1995)
# - How to Make an American Quilt (1995)
# - Pocahontas (1995)
# - Sense and Sensibility (1995)
# - Leaving Las Vegas (1995)
# - Persuasion (1995)
# - Twelve Monkeys (1995)
# - Dead Man Walking (1995)
# - Richard III (1995)
# - Postino, Il (The Postman) (1994)
# - Braveheart (1995)
# - Brothers McMullen, The (1995)
# - Umbrellas of Cherbourg, The (Parapluies de Cherbourg, Les) (1964)
# - Jumanji (1995)
# - Grumpier Old Men (1995)
# - Heat (1995)
# - Sabrina (1995)
# - American President, The (1995)
# - Casino (1995)
# - Get Shorty (1995)
# - Leaving Las Vegas (1995)
# - City of Lost Children, The (1995)
# - Twelve Monkeys (1995)
# - Usual Suspects, The (1995)
# - Taxi Driver (1976)
# - Star Wars: Episode IV - A New Hope (1977)
# - Pulp Fiction (1994)
# - Shawshank Redemption, The (1994)
# - Silence of the Lambs, The (1991)
# - Snow White and the Seven Dwarfs (1937)
# - Godfather, The (1972)
# - Philadelphia Story, The (1940)
# - Singin' in the Rain (1952)
# - Toy Story (1995)
# - American President, The (1995)
# - Sense and Sensibility (1995)
# - Twelve Monkeys (1995)
# - Clueless (1995)
# - Richard III (1995)
# - Seven (Se7en) (1995)
# - Usual Suspects, The (1995)
# - Juror, The (1996)
# - Things to Do in Denver when You're Dead (1995)
# - Toy Story (1995)
# - Jumanji (1995)
# - GoldenEye (1995)
# - American President, The (1995)
# - Nixon (1995)
# - Casino (1995)
# - Copycat (1995)
# - Twelve Monkeys (1995)
# - Clueless (1995)
# - To Die For (1995)
# - Toy Story (1995)
# - Babe (1995)
# - Muppet Treasure Island (1996)
# - Braveheart (1995)
# - Crumb (1994)
# - Mallrats (1995)
# - Unzipped (1995)
# - Ed Wood (1994)
# - Interview with the Vampire (1994)
# - Star Wars: Episode IV - A New Hope (1977)
#
# Cluster 2 (K-means):
# - Toy Story (1995)
# - Jumanji (1995)
# - Sabrina (1995)
# - Powder (1995)
# - Twelve Monkeys (1995)
# - Pocahontas (1995)
# - Mr. Holland's Opus (1995)
# - Happy Gilmore (1996)
# - Braveheart (1995)
# - Anne Frank Remembered (1995)
# - Toy Story (1995)
# - Jumanji (1995)
# - GoldenEye (1995)
# - Sense and Sensibility (1995)
# - Othello (1995)
# - City of Lost Children, The (1995)
# - Babe (1995)
# - Mortal Kombat (1995)
# - Seven (Se7en) (1995)
# - Pocahontas (1995)
# - Toy Story (1995)
# - GoldenEye (1995)
# - Sense and Sensibility (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Seven (Se7en) (1995)
# - Screamers (1995)
# - Braveheart (1995)
# - Taxi Driver (1976)
# - Die Hard: With a Vengeance (1995)
# - GoldenEye (1995)
# - Casino (1995)
# - Twelve Monkeys (1995)
# - Clueless (1995)
# - Seven (Se7en) (1995)
# - Bio-Dome (1996)
# - From Dusk Till Dawn (1996)
# - Things to Do in Denver when You're Dead (1995)
# - Broken Arrow (1996)
# - Happy Gilmore (1996)
# - Toy Story (1995)
# - Grumpier Old Men (1995)
# - Waiting to Exhale (1995)
# - Father of the Bride Part II (1995)
# - Sabrina (1995)
# - American President, The (1995)
# - Casino (1995)
# - It Takes Two (1995)
# - Clueless (1995)
# - To Die For (1995)
# - Toy Story (1995)
# - Heat (1995)
# - Sabrina (1995)
# - GoldenEye (1995)
# - American President, The (1995)
# - Casino (1995)
# - Get Shorty (1995)
# - Shanghai Triad (Yao a yao yao dao waipo qiao) (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Heat (1995)
# - GoldenEye (1995)
# - Powder (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Lawnmower Man 2: Beyond Cyberspace (1996)
# - Die Hard: With a Vengeance (1995)
# - Johnny Mnemonic (1995)
# - Judge Dredd (1995)
# - Net, The (1995)
# - Toy Story (1995)
# - Jumanji (1995)
# - Father of the Bride Part II (1995)
# - Heat (1995)
# - Sabrina (1995)
# - GoldenEye (1995)
# - Cutthroat Island (1995)
# - Sense and Sensibility (1995)
# - Ace Ventura: When Nature Calls (1995)
# - Get Shorty (1995)
# - Sense and Sensibility (1995)
# - Get Shorty (1995)
# - City of Lost Children, The (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Clueless (1995)
# - Lawnmower Man 2: Beyond Cyberspace (1996)
# - From Dusk Till Dawn (1996)
# - Broken Arrow (1996)
# - Braveheart (1995)
# - Toy Story (1995)
# - Tom and Huck (1995)
# - Sudden Death (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Clueless (1995)
# - Mortal Kombat (1995)
# - Seven (Se7en) (1995)
# - Lawnmower Man 2: Beyond Cyberspace (1996)
# - From Dusk Till Dawn (1996)
#
# Cluster 3 (K-means):
# - Sabrina (1995)
# - Get Shorty (1995)
# - Seven (Se7en) (1995)
# - Usual Suspects, The (1995)
# - Home for the Holidays (1995)
# - Indian in the Cupboard, The (1995)
# - From Dusk Till Dawn (1996)
# - Nick of Time (1995)
# - Down Periscope (1996)
# - Up Close and Personal (1996)
#
# Cluster 4 (K-means):
# - Toy Story (1995)
# - Heat (1995)
# - GoldenEye (1995)
# - City of Lost Children, The (1995)
# - Carrington (1995)
# - Seven (Se7en) (1995)
# - Usual Suspects, The (1995)
# - Heidi Fleiss: Hollywood Madam (1995)
# - Taxi Driver (1976)
# - Belle de jour (1967)
# - Toy Story (1995)
# - Waiting to Exhale (1995)
# - American President, The (1995)
# - Nixon (1995)
# - Casino (1995)
# - Sense and Sensibility (1995)
# - Get Shorty (1995)
# - Leaving Las Vegas (1995)
# - Babe (1995)
# - Carrington (1995)
# - Get Shorty (1995)
# - Leaving Las Vegas (1995)
# - Persuasion (1995)
# - City of Lost Children, The (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Clueless (1995)
# - Usual Suspects, The (1995)
# - Nico Icon (1995)
# - Braveheart (1995)
# - Grumpier Old Men (1995)
# - Father of the Bride Part II (1995)
# - Heat (1995)
# - Sabrina (1995)
# - American President, The (1995)
# - Nixon (1995)
# - Casino (1995)
# - Sense and Sensibility (1995)
# - Four Rooms (1995)
# - Ace Ventura: When Nature Calls (1995)
# - Heat (1995)
# - Sabrina (1995)
# - American President, The (1995)
# - Casino (1995)
# - Sense and Sensibility (1995)
# - Money Train (1995)
# - Get Shorty (1995)
# - Copycat (1995)
# - Powder (1995)
# - Leaving Las Vegas (1995)
# - Toy Story (1995)
# - Jumanji (1995)
# - Grumpier Old Men (1995)
# - Father of the Bride Part II (1995)
# - Sabrina (1995)
# - American President, The (1995)
# - Cutthroat Island (1995)
# - Sense and Sensibility (1995)
# - Get Shorty (1995)
# - Leaving Las Vegas (1995)
# - Toy Story (1995)
# - Grumpier Old Men (1995)
# - Waiting to Exhale (1995)
# - Heat (1995)
# - GoldenEye (1995)
# - American President, The (1995)
# - Casino (1995)
# - Four Rooms (1995)
# - Get Shorty (1995)
# - Copycat (1995)
# - Toy Story (1995)
# - Heat (1995)
# - Sabrina (1995)
# - GoldenEye (1995)
# - American President, The (1995)
# - Nixon (1995)
# - Casino (1995)
# - Sense and Sensibility (1995)
# - Powder (1995)
# - Leaving Las Vegas (1995)
# - Dead Man Walking (1995)
# - Clueless (1995)
# - To Die For (1995)
# - Mr. Holland's Opus (1995)
# - From Dusk Till Dawn (1996)
# - White Balloon, The (Badkonake Sefid ) (1995)
# - Heidi Fleiss: Hollywood Madam (1995)
# - From the Journals of Jean Seberg (1995)
# - Belle de jour (1967)
# - Canadian Bacon (1994)
# - Toy Story (1995)
# - Grumpier Old Men (1995)
# - Sabrina (1995)
# - American President, The (1995)
# - Dracula: Dead and Loving It (1995)
# - Cutthroat Island (1995)
# - Casino (1995)
# - Sense and Sensibility (1995)
# - Get Shorty (1995)
# - Leaving Las Vegas (1995)
#
# Cluster 5 (K-means):
# - Jumanji (1995)
# - Casino (1995)
# - Sense and Sensibility (1995)
# - Four Rooms (1995)
# - Get Shorty (1995)
# - Copycat (1995)
# - Leaving Las Vegas (1995)
# - City of Lost Children, The (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Toy Story (1995)
# - Jumanji (1995)
# - Sabrina (1995)
# - GoldenEye (1995)
# - American President, The (1995)
# - Cutthroat Island (1995)
# - Sense and Sensibility (1995)
# - Assassins (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Toy Story (1995)
# - Jumanji (1995)
# - Heat (1995)
# - Tom and Huck (1995)
# - Dracula: Dead and Loving It (1995)
# - Casino (1995)
# - Sense and Sensibility (1995)
# - Four Rooms (1995)
# - Ace Ventura: When Nature Calls (1995)
# - Money Train (1995)
# - Toy Story (1995)
# - Grumpier Old Men (1995)
# - Father of the Bride Part II (1995)
# - Heat (1995)
# - GoldenEye (1995)
# - American President, The (1995)
# - Dracula: Dead and Loving It (1995)
# - Casino (1995)
# - Ace Ventura: When Nature Calls (1995)
# - Money Train (1995)
# - Grumpier Old Men (1995)
# - Waiting to Exhale (1995)
# - Sabrina (1995)
# - GoldenEye (1995)
# - American President, The (1995)
# - Ace Ventura: When Nature Calls (1995)
# - Get Shorty (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Dead Man Walking (1995)
# - Toy Story (1995)
# - Jumanji (1995)
# - Father of the Bride Part II (1995)
# - Heat (1995)
# - Sudden Death (1995)
# - GoldenEye (1995)
# - American President, The (1995)
# - Dracula: Dead and Loving It (1995)
# - Nixon (1995)
# - Cutthroat Island (1995)
# - Toy Story (1995)
# - Father of the Bride Part II (1995)
# - Heat (1995)
# - Sabrina (1995)
# - GoldenEye (1995)
# - American President, The (1995)
# - Nixon (1995)
# - Cutthroat Island (1995)
# - Casino (1995)
# - Money Train (1995)
# - Toy Story (1995)
# - Jumanji (1995)
# - Heat (1995)
# - GoldenEye (1995)
# - American President, The (1995)
# - Dracula: Dead and Loving It (1995)
# - Sense and Sensibility (1995)
# - Get Shorty (1995)
# - Copycat (1995)
# - Leaving Las Vegas (1995)
# - Toy Story (1995)
# - Grumpier Old Men (1995)
# - Father of the Bride Part II (1995)
# - Heat (1995)
# - Sabrina (1995)
# - GoldenEye (1995)
# - American President, The (1995)
# - Casino (1995)
# - Sense and Sensibility (1995)
# - Ace Ventura: When Nature Calls (1995)
# - Toy Story (1995)
# - Grumpier Old Men (1995)
# - Father of the Bride Part II (1995)
# - Heat (1995)
# - Sabrina (1995)
# - Sudden Death (1995)
# - American President, The (1995)
# - Nixon (1995)
# - Cutthroat Island (1995)
# - Casino (1995)
#
# Cluster 6 (K-means):
# - Toy Story (1995)
# - Pocahontas (1995)
# - Apollo 13 (1995)
# - Star Wars: Episode IV - A New Hope (1977)
# - Schindler's List (1993)
# - Secret Garden, The (1993)
# - Aladdin (1992)
# - Snow White and the Seven Dwarfs (1937)
# - Beauty and the Beast (1991)
# - Fargo (1996)
# - Get Shorty (1995)
# - Broken Arrow (1996)
# - Braveheart (1995)
# - Desperado (1995)
# - Die Hard: With a Vengeance (1995)
# - Ed Wood (1994)
# - Like Water for Chocolate (Como agua para chocolate) (1992)
# - Outbreak (1995)
# - Shawshank Redemption, The (1994)
# - Clear and Present Danger (1994)
# - Happy Gilmore (1996)
# - Star Wars: Episode IV - A New Hope (1977)
# - Jurassic Park (1993)
# - Three Musketeers, The (1993)
# - Dances with Wolves (1990)
# - Silence of the Lambs, The (1991)
# - Mission: Impossible (1996)
# - Dragonheart (1996)
# - Rock, The (1996)
# - Ghost and the Darkness, The (1996)
# - Star Wars: Episode IV - A New Hope (1977)
# - Jurassic Park (1993)
# - Die Hard (1988)
# - E.T. the Extra-Terrestrial (1982)
# - Star Wars: Episode V - The Empire Strikes Back (1980)
# - Raiders of the Lost Ark (1981)
# - Good, The Bad and The Ugly, The (1966)
# - Star Wars: Episode VI - Return of the Jedi (1983)
# - Alien (1979)
# - Terminator, The (1984)
# - Heat (1995)
# - Casino (1995)
# - Powder (1995)
# - City of Lost Children, The (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Dead Man Walking (1995)
# - Clueless (1995)
# - Richard III (1995)
# - Seven (Se7en) (1995)
# - Toy Story (1995)
# - Sense and Sensibility (1995)
# - Babe (1995)
# - Pocahontas (1995)
# - Umbrellas of Cherbourg, The (Parapluies de Cherbourg, Les) (1964)
# - Legends of the Fall (1994)
# - Pulp Fiction (1994)
# - Lion King, The (1994)
# - Maverick (1994)
# - Speed (1994)
# - Heat (1995)
# - Braveheart (1995)
# - Clear and Present Danger (1994)
# - Speed (1994)
# - True Lies (1994)
# - Demolition Man (1993)
# - Fugitive, The (1993)
# - In the Line of Fire (1993)
# - Jurassic Park (1993)
# - Terminator 2: Judgment Day (1991)
# - Toy Story (1995)
# - Waiting to Exhale (1995)
# - Nixon (1995)
# - Casino (1995)
# - Sense and Sensibility (1995)
# - Powder (1995)
# - Leaving Las Vegas (1995)
# - Dead Man Walking (1995)
# - Clueless (1995)
# - Dead Presidents (1995)
# - Toy Story (1995)
# - Casino (1995)
# - Leaving Las Vegas (1995)
# - Seven (Se7en) (1995)
# - Usual Suspects, The (1995)
# - Apollo 13 (1995)
# - Crumb (1994)
# - Clerks (1994)
# - Quiz Show (1994)
# - Shawshank Redemption, The (1994)
# - Dead Man Walking (1995)
# - Seven (Se7en) (1995)
# - Usual Suspects, The (1995)
# - Angels and Insects (1995)
# - Black Sheep (1996)
# - Happy Gilmore (1996)
# - Braveheart (1995)
# - Billy Madison (1995)
# - Dumb & Dumber (1994)
# - Hoop Dreams (1994)
#
# Cluster 7 (K-means):
# - Jumanji (1995)
# - Grumpier Old Men (1995)
# - Waiting to Exhale (1995)
# - Father of the Bride Part II (1995)
# - Heat (1995)
# - Sabrina (1995)
# - GoldenEye (1995)
# - American President, The (1995)
# - Dracula: Dead and Loving It (1995)
# - Nixon (1995)
#
# Cluster 8 (K-means):
# - Grumpier Old Men (1995)
# - Tom and Huck (1995)
# - Cutthroat Island (1995)
# - Money Train (1995)
# - Powder (1995)
# - Now and Then (1995)
# - Babe (1995)
# - Dead Man Walking (1995)
# - Clueless (1995)
# - Mortal Kombat (1995)
#
# Cluster 9 (K-means):
# - Toy Story (1995)
# - Jumanji (1995)
# - Grumpier Old Men (1995)
# - Father of the Bride Part II (1995)
# - Heat (1995)
# - Sabrina (1995)
# - GoldenEye (1995)
# - American President, The (1995)
# - Dracula: Dead and Loving It (1995)
# - Balto (1995)
#
# Cluster 0 (Clustering Hierárquico):
# - Toy Story (1995)
# - Pocahontas (1995)
# - Apollo 13 (1995)
# - Star Wars: Episode IV - A New Hope (1977)
# - Schindler's List (1993)
# - Secret Garden, The (1993)
# - Aladdin (1992)
# - Snow White and the Seven Dwarfs (1937)
# - Beauty and the Beast (1991)
# - Fargo (1996)
# - Get Shorty (1995)
# - Broken Arrow (1996)
# - Braveheart (1995)
# - Desperado (1995)
# - Die Hard: With a Vengeance (1995)
# - Ed Wood (1994)
# - Like Water for Chocolate (Como agua para chocolate) (1992)
# - Outbreak (1995)
# - Shawshank Redemption, The (1994)
# - Clear and Present Danger (1994)
# - Happy Gilmore (1996)
# - Star Wars: Episode IV - A New Hope (1977)
# - Jurassic Park (1993)
# - Three Musketeers, The (1993)
# - Dances with Wolves (1990)
# - Silence of the Lambs, The (1991)
# - Mission: Impossible (1996)
# - Dragonheart (1996)
# - Rock, The (1996)
# - Ghost and the Darkness, The (1996)
# - Star Wars: Episode IV - A New Hope (1977)
# - Jurassic Park (1993)
# - Die Hard (1988)
# - E.T. the Extra-Terrestrial (1982)
# - Star Wars: Episode V - The Empire Strikes Back (1980)
# - Raiders of the Lost Ark (1981)
# - Good, The Bad and The Ugly, The (1966)
# - Star Wars: Episode VI - Return of the Jedi (1983)
# - Alien (1979)
# - Terminator, The (1984)
# - Toy Story (1995)
# - Sense and Sensibility (1995)
# - Babe (1995)
# - Pocahontas (1995)
# - Umbrellas of Cherbourg, The (Parapluies de Cherbourg, Les) (1964)
# - Legends of the Fall (1994)
# - Pulp Fiction (1994)
# - Lion King, The (1994)
# - Maverick (1994)
# - Speed (1994)
# - Heat (1995)
# - Braveheart (1995)
# - Clear and Present Danger (1994)
# - Speed (1994)
# - True Lies (1994)
# - Demolition Man (1993)
# - Fugitive, The (1993)
# - In the Line of Fire (1993)
# - Jurassic Park (1993)
# - Terminator 2: Judgment Day (1991)
# - Toy Story (1995)
# - Casino (1995)
# - Leaving Las Vegas (1995)
# - Seven (Se7en) (1995)
# - Usual Suspects, The (1995)
# - Apollo 13 (1995)
# - Crumb (1994)
# - Clerks (1994)
# - Quiz Show (1994)
# - Shawshank Redemption, The (1994)
# - Dead Man Walking (1995)
# - Seven (Se7en) (1995)
# - Usual Suspects, The (1995)
# - Angels and Insects (1995)
# - Black Sheep (1996)
# - Happy Gilmore (1996)
# - Braveheart (1995)
# - Billy Madison (1995)
# - Dumb & Dumber (1994)
# - Hoop Dreams (1994)
# - Taxi Driver (1976)
# - Silence of the Lambs, The (1991)
# - Larger Than Life (1996)
# - Godfather, The (1972)
# - Wizard of Oz, The (1939)
# - Citizen Kane (1941)
# - Father of the Bride (1950)
# - 2 Days in the Valley (1996)
# - One Flew Over the Cuckoo's Nest (1975)
# - Raiders of the Lost Ark (1981)
# - Jumanji (1995)
# - GoldenEye (1995)
# - Get Shorty (1995)
# - Usual Suspects, The (1995)
# - Indian in the Cupboard, The (1995)
# - Braveheart (1995)
# - Batman Forever (1995)
# - Die Hard: With a Vengeance (1995)
# - Star Wars: Episode IV - A New Hope (1977)
# - Pulp Fiction (1994)
#
# Cluster 1 (Clustering Hierárquico):
# - Toy Story (1995)
# - Jumanji (1995)
# - GoldenEye (1995)
# - Sense and Sensibility (1995)
# - Othello (1995)
# - City of Lost Children, The (1995)
# - Babe (1995)
# - Mortal Kombat (1995)
# - Seven (Se7en) (1995)
# - Pocahontas (1995)
# - Toy Story (1995)
# - GoldenEye (1995)
# - Sense and Sensibility (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Seven (Se7en) (1995)
# - Screamers (1995)
# - Braveheart (1995)
# - Taxi Driver (1976)
# - Die Hard: With a Vengeance (1995)
# - Toy Story (1995)
# - Grumpier Old Men (1995)
# - Waiting to Exhale (1995)
# - Father of the Bride Part II (1995)
# - Sabrina (1995)
# - American President, The (1995)
# - Casino (1995)
# - It Takes Two (1995)
# - Clueless (1995)
# - To Die For (1995)
# - Casino (1995)
# - Sense and Sensibility (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Dead Man Walking (1995)
# - Seven (Se7en) (1995)
# - Usual Suspects, The (1995)
# - Braveheart (1995)
# - Taxi Driver (1976)
# - Apollo 13 (1995)
# - Sabrina (1995)
# - Sense and Sensibility (1995)
# - Persuasion (1995)
# - Dead Man Walking (1995)
# - Clueless (1995)
# - Postino, Il (The Postman) (1994)
# - Chungking Express (1994)
# - Belle de jour (1967)
# - Beyond Rangoon (1995)
# - Pulp Fiction (1994)
# - Jumanji (1995)
# - Indian in the Cupboard, The (1995)
# - Crimson Tide (1995)
# - Judge Dredd (1995)
# - Kid in King Arthur's Court, A (1995)
# - Quick and the Dead, The (1995)
# - Star Trek: Generations (1994)
# - Forrest Gump (1994)
# - Black Beauty (1994)
# - Hot Shots! Part Deux (1993)
# - Wes Craven's New Nightmare (1994)
# - Searching for Bobby Fischer (1993)
# - Big Squeeze, The (1996)
# - Halloween: The Curse of Michael Myers (1995)
# - American Strays (1996)
# - Evil Dead II (Dead By Dawn) (1987)
# - Night on Earth (1991)
# - Amityville Horror, The (1979)
# - Nightmare on Elm Street, A (1984)
# - Scream (1996)
# - Sense and Sensibility (1995)
# - Get Shorty (1995)
# - City of Lost Children, The (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Clueless (1995)
# - Lawnmower Man 2: Beyond Cyberspace (1996)
# - From Dusk Till Dawn (1996)
# - Broken Arrow (1996)
# - Braveheart (1995)
# - Toy Story (1995)
# - American President, The (1995)
# - Babe (1995)
# - Clueless (1995)
# - Mighty Aphrodite (1995)
# - Kicking and Screaming (1995)
# - Last Summer in the Hamptons (1995)
# - Muppet Treasure Island (1996)
# - Brothers McMullen, The (1995)
# - Blue in the Face (1995)
# - Heat (1995)
# - GoldenEye (1995)
# - Get Shorty (1995)
# - Mortal Kombat (1995)
# - Pocahontas (1995)
# - Broken Arrow (1996)
# - Rumble in the Bronx (1995)
# - Bad Boys (1995)
# - Batman Forever (1995)
# - Desperado (1995)
#
# Cluster 2 (Clustering Hierárquico):
# - Toy Story (1995)
# - Balto (1995)
# - Get Shorty (1995)
# - Nick of Time (1995)
# - Broken Arrow (1996)
# - Rumble in the Bronx (1995)
# - Clockers (1995)
# - Strange Days (1995)
# - Natural Born Killers (1994)
# - Pulp Fiction (1994)
# - Canadian Bacon (1994)
# - Die Hard: With a Vengeance (1995)
# - Star Wars: Episode IV - A New Hope (1977)
# - Santa Clause, The (1994)
# - Mask, The (1994)
# - Substitute, The (1996)
# - Kingpin (1996)
# - Nutty Professor, The (1996)
# - Godfather, The (1972)
# - 2001: A Space Odyssey (1968)
# - Heat (1995)
# - GoldenEye (1995)
# - Get Shorty (1995)
# - From Dusk Till Dawn (1996)
# - Braveheart (1995)
# - Desperado (1995)
# - Strange Days (1995)
# - Star Wars: Episode IV - A New Hope (1977)
# - Legends of the Fall (1994)
# - Natural Born Killers (1994)
# - Grumpier Old Men (1995)
# - Man of the House (1995)
# - National Lampoon's Senior Trip (1995)
# - Little Big League (1994)
# - Fargo (1996)
# - Space Jam (1996)
# - D3: The Mighty Ducks (1996)
# - Spice World (1997)
# - 10 Things I Hate About You (1999)
# - Big Daddy (1999)
# - GoldenEye (1995)
# - Get Shorty (1995)
# - Braveheart (1995)
# - Star Wars: Episode IV - A New Hope (1977)
# - Natural Born Killers (1994)
# - Crow, The (1994)
# - Speed (1994)
# - Low Down Dirty Shame, A (1994)
# - Fugitive, The (1993)
# - Jurassic Park (1993)
# - Leaving Las Vegas (1995)
# - Twelve Monkeys (1995)
# - Seven (Se7en) (1995)
# - Usual Suspects, The (1995)
# - Postino, Il (The Postman) (1994)
# - Braveheart (1995)
# - Taxi Driver (1976)
# - Crumb (1994)
# - Hoop Dreams (1994)
# - Star Wars: Episode IV - A New Hope (1977)
# - Casino (1995)
# - Dead Presidents (1995)
# - Broken Arrow (1996)
# - Braveheart (1995)
# - Devil in a Blue Dress (1995)
# - Waterworld (1995)
# - Natural Born Killers (1994)
# - Outbreak (1995)
# - River Wild, The (1994)
# - Speed (1994)
# - Get Shorty (1995)
# - Powder (1995)
# - Twelve Monkeys (1995)
# - Braveheart (1995)
# - Apollo 13 (1995)
# - Clerks (1994)
# - Ed Wood (1994)
# - Star Wars: Episode IV - A New Hope (1977)
# - Pulp Fiction (1994)
# - Quiz Show (1994)
# - Get Shorty (1995)
# - Braveheart (1995)
# - Star Wars: Episode IV - A New Hope (1977)
# - Clear and Present Danger (1994)
# - Speed (1994)
# - True Lies (1994)
# - In the Line of Fire (1993)
# - Jurassic Park (1993)
# - Executive Decision (1996)
# - Rock, The (1996)
# - Heat (1995)
# - Get Shorty (1995)
# - Powder (1995)
# - Usual Suspects, The (1995)
# - Braveheart (1995)
# - Taxi Driver (1976)
# - Rumble in the Bronx (1995)
# - Clerks (1994)
# - Star Wars: Episode IV - A New Hope (1977)
# - Shawshank Redemption, The (1994)
#
# Cluster 3 (Clustering Hierárquico):
# - Heat (1995)
# - Twelve Monkeys (1995)
# - Seven (Se7en) (1995)
# - Usual Suspects, The (1995)
# - From Dusk Till Dawn (1996)
# - Misérables, Les (1995)
# - Happy Gilmore (1996)
# - Braveheart (1995)
# - Birdcage, The (1996)
# - Congo (1995)
# - Toy Story (1995)
# - Sabrina (1995)
# - American President, The (1995)
# - Sense and Sensibility (1995)
# - Babe (1995)
# - Clueless (1995)
# - Desperado (1995)
# - Circle of Friends (1995)
# - French Kiss (1995)
# - Shawshank Redemption, The (1994)
# - Toy Story (1995)
# - Jumanji (1995)
# - Sense and Sensibility (1995)
# - Babe (1995)
# - Muppet Treasure Island (1996)
# - Rob Roy (1995)
# - Immortal Beloved (1994)
# - Star Wars: Episode IV - A New Hope (1977)
# - Stargate (1994)
# - Santa Clause, The (1994)
# - Jumanji (1995)
# - Grumpier Old Men (1995)
# - Heat (1995)
# - Sabrina (1995)
# - American President, The (1995)
# - Casino (1995)
# - Get Shorty (1995)
# - Leaving Las Vegas (1995)
# - City of Lost Children, The (1995)
# - Twelve Monkeys (1995)
# - Toy Story (1995)
# - Tom and Huck (1995)
# - Sudden Death (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Clueless (1995)
# - Mortal Kombat (1995)
# - Seven (Se7en) (1995)
# - Lawnmower Man 2: Beyond Cyberspace (1996)
# - From Dusk Till Dawn (1996)
# - Toy Story (1995)
# - Dracula: Dead and Loving It (1995)
# - Ace Ventura: When Nature Calls (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - To Die For (1995)
# - Seven (Se7en) (1995)
# - Usual Suspects, The (1995)
# - Indian in the Cupboard, The (1995)
# - Don't Be a Menace to South Central While Drinking Your Juice in the Hood (1996)
# - Get Shorty (1995)
# - Fair Game (1995)
# - Bad Boys (1995)
# - Die Hard: With a Vengeance (1995)
# - Waterworld (1995)
# - Star Wars: Episode IV - A New Hope (1977)
# - Outbreak (1995)
# - Star Trek: Generations (1994)
# - I Love Trouble (1994)
# - Maverick (1994)
# - Sudden Death (1995)
# - Cutthroat Island (1995)
# - Get Shorty (1995)
# - From Dusk Till Dawn (1996)
# - Nick of Time (1995)
# - Broken Arrow (1996)
# - Braveheart (1995)
# - Batman Forever (1995)
# - Congo (1995)
# - Die Hard: With a Vengeance (1995)
# - Toy Story (1995)
# - Heat (1995)
# - American President, The (1995)
# - Nixon (1995)
# - Casino (1995)
# - Money Train (1995)
# - Get Shorty (1995)
# - Copycat (1995)
# - Leaving Las Vegas (1995)
# - Dead Man Walking (1995)
# - Toy Story (1995)
# - Heat (1995)
# - GoldenEye (1995)
# - Cutthroat Island (1995)
# - Money Train (1995)
# - Get Shorty (1995)
# - Powder (1995)
# - Twelve Monkeys (1995)
# - Mortal Kombat (1995)
# - Broken Arrow (1996)
#
# Cluster 4 (Clustering Hierárquico):
# - Usual Suspects, The (1995)
# - Braveheart (1995)
# - Batman Forever (1995)
# - Kids (1995)
# - Waterworld (1995)
# - Star Wars: Episode IV - A New Hope (1977)
# - Little Women (1994)
# - Legends of the Fall (1994)
# - Pulp Fiction (1994)
# - Quick and the Dead, The (1995)
# - Sense and Sensibility (1995)
# - Leaving Las Vegas (1995)
# - Persuasion (1995)
# - Twelve Monkeys (1995)
# - Dead Man Walking (1995)
# - Richard III (1995)
# - Postino, Il (The Postman) (1994)
# - Braveheart (1995)
# - Brothers McMullen, The (1995)
# - Umbrellas of Cherbourg, The (Parapluies de Cherbourg, Les) (1964)
# - Nixon (1995)
# - Sense and Sensibility (1995)
# - Leaving Las Vegas (1995)
# - Othello (1995)
# - Cry, the Beloved Country (1995)
# - Postino, Il (The Postman) (1994)
# - Angels and Insects (1995)
# - Crimson Tide (1995)
# - Eat Drink Man Woman (1994)
# - Like Water for Chocolate (Como agua para chocolate) (1992)
# - Friday (1995)
# - Taxi Driver (1976)
# - Clerks (1994)
# - Hoop Dreams (1994)
# - Star Wars: Episode IV - A New Hope (1977)
# - Pulp Fiction (1994)
# - Tales from the Hood (1995)
# - Killing Zoe (1994)
# - Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)
# - Vertigo (1958)
# - American President, The (1995)
# - Braveheart (1995)
# - Taxi Driver (1976)
# - Shawshank Redemption, The (1994)
# - Jurassic Park (1993)
# - Schindler's List (1993)
# - Blade Runner (1982)
# - Fargo (1996)
# - Godfather, The (1972)
# - North by Northwest (1959)
# - Usual Suspects, The (1995)
# - Taxi Driver (1976)
# - Star Wars: Episode IV - A New Hope (1977)
# - Pulp Fiction (1994)
# - Shawshank Redemption, The (1994)
# - Silence of the Lambs, The (1991)
# - Snow White and the Seven Dwarfs (1937)
# - Godfather, The (1972)
# - Philadelphia Story, The (1940)
# - Singin' in the Rain (1952)
# - Toy Story (1995)
# - Lion King, The (1994)
# - Blade Runner (1982)
# - Aladdin (1992)
# - Snow White and the Seven Dwarfs (1937)
# - Beauty and the Beast (1991)
# - Pinocchio (1940)
# - Ghost in the Shell (Kokaku kidotai) (1995)
# - Close Shave, A (1995)
# - Maltese Falcon, The (1941)
# - Jeffrey (1995)
# - Star Wars: Episode IV - A New Hope (1977)
# - Muriel's Wedding (1994)
# - Faster Pussycat! Kill! Kill! (1965)
# - Age of Innocence, The (1993)
# - Go Fish (1994)
# - Terminator 2: Judgment Day (1991)
# - Mission: Impossible (1996)
# - Godfather, The (1972)
# - Breakfast at Tiffany's (1961)
# - Toy Story (1995)
# - American President, The (1995)
# - Sense and Sensibility (1995)
# - Twelve Monkeys (1995)
# - Clueless (1995)
# - Richard III (1995)
# - Seven (Se7en) (1995)
# - Usual Suspects, The (1995)
# - Juror, The (1996)
# - Things to Do in Denver when You're Dead (1995)
# - Toy Story (1995)
# - Powder (1995)
# - Leaving Las Vegas (1995)
# - Babe (1995)
# - Taxi Driver (1976)
# - Brothers McMullen, The (1995)
# - Apollo 13 (1995)
# - Crumb (1994)
# - Jeffrey (1995)
# - Moonlight and Valentino (1995)
#
# Cluster 5 (Clustering Hierárquico):
# - Heat (1995)
# - GoldenEye (1995)
# - Powder (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Lawnmower Man 2: Beyond Cyberspace (1996)
# - Die Hard: With a Vengeance (1995)
# - Johnny Mnemonic (1995)
# - Judge Dredd (1995)
# - Net, The (1995)
# - Jumanji (1995)
# - Johnny Mnemonic (1995)
# - Species (1995)
# - Star Wars: Episode IV - A New Hope (1977)
# - Stargate (1994)
# - Santa Clause, The (1994)
# - Tank Girl (1995)
# - Mask, The (1994)
# - Highlander III: The Sorcerer (1994)
# - Coneheads (1993)
# - Twelve Monkeys (1995)
# - Lawnmower Man 2: Beyond Cyberspace (1996)
# - Johnny Mnemonic (1995)
# - Net, The (1995)
# - Species (1995)
# - Strange Days (1995)
# - Junior (1994)
# - Star Wars: Episode IV - A New Hope (1977)
# - Stargate (1994)
# - Star Trek: Generations (1994)
# - GoldenEye (1995)
# - Dead Presidents (1995)
# - Usual Suspects, The (1995)
# - Die Hard: With a Vengeance (1995)
# - Net, The (1995)
# - Star Wars: Episode IV - A New Hope (1977)
# - Clear and Present Danger (1994)
# - Forrest Gump (1994)
# - Speed (1994)
# - True Lies (1994)
# - Grumpier Old Men (1995)
# - Powder (1995)
# - Twelve Monkeys (1995)
# - Screamers (1995)
# - Taxi Driver (1976)
# - Congo (1995)
# - Johnny Mnemonic (1995)
# - Judge Dredd (1995)
# - Net, The (1995)
# - Species (1995)
# - Heat (1995)
# - GoldenEye (1995)
# - Get Shorty (1995)
# - Fair Game (1995)
# - Broken Arrow (1996)
# - Braveheart (1995)
# - Rumble in the Bronx (1995)
# - Desperado (1995)
# - Die Hard: With a Vengeance (1995)
# - Under Siege 2: Dark Territory (1995)
# - Toy Story (1995)
# - Get Shorty (1995)
# - Powder (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Seven (Se7en) (1995)
# - Screamers (1995)
# - Taxi Driver (1976)
# - Birdcage, The (1996)
# - Congo (1995)
# - Toy Story (1995)
# - Cutthroat Island (1995)
# - Twelve Monkeys (1995)
# - Dead Man Walking (1995)
# - Mortal Kombat (1995)
# - How to Make an American Quilt (1995)
# - Seven (Se7en) (1995)
# - Usual Suspects, The (1995)
# - Mr. Holland's Opus (1995)
# - Lawnmower Man 2: Beyond Cyberspace (1996)
# - Twelve Monkeys (1995)
# - Lawnmower Man 2: Beyond Cyberspace (1996)
# - Screamers (1995)
# - Johnny Mnemonic (1995)
# - Judge Dredd (1995)
# - Species (1995)
# - Strange Days (1995)
# - Star Wars: Episode IV - A New Hope (1977)
# - Stargate (1994)
# - Tank Girl (1995)
# - Toy Story (1995)
# - Heat (1995)
# - Sudden Death (1995)
# - GoldenEye (1995)
# - Get Shorty (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Broken Arrow (1996)
# - Happy Gilmore (1996)
# - Braveheart (1995)
#
# Cluster 6 (Clustering Hierárquico):
# - Toy Story (1995)
# - Jumanji (1995)
# - Tom and Huck (1995)
# - Balto (1995)
# - Ace Ventura: When Nature Calls (1995)
# - Babe (1995)
# - Pocahontas (1995)
# - Indian in the Cupboard, The (1995)
# - Dunston Checks In (1996)
# - Muppet Treasure Island (1996)
# - Toy Story (1995)
# - Jumanji (1995)
# - Balto (1995)
# - Babe (1995)
# - Pocahontas (1995)
# - Indian in the Cupboard, The (1995)
# - Misérables, Les (1995)
# - Muppet Treasure Island (1996)
# - Star Wars: Episode IV - A New Hope (1977)
# - Jungle Book, The (1994)
# - Toy Story (1995)
# - Babe (1995)
# - Muppet Treasure Island (1996)
# - Braveheart (1995)
# - Crumb (1994)
# - Mallrats (1995)
# - Unzipped (1995)
# - Ed Wood (1994)
# - Interview with the Vampire (1994)
# - Star Wars: Episode IV - A New Hope (1977)
# - Toy Story (1995)
# - Sabrina (1995)
# - American President, The (1995)
# - Sense and Sensibility (1995)
# - Get Shorty (1995)
# - Leaving Las Vegas (1995)
# - How to Make an American Quilt (1995)
# - Postino, Il (The Postman) (1994)
# - From Dusk Till Dawn (1996)
# - White Squall (1996)
# - Toy Story (1995)
# - Powder (1995)
# - Usual Suspects, The (1995)
# - Star Wars: Episode IV - A New Hope (1977)
# - Professional, The (a.k.a. Leon: The Professional) (1994)
# - Pulp Fiction (1994)
# - Shawshank Redemption, The (1994)
# - Lion King, The (1994)
# - Schindler's List (1993)
# - Terminator 2: Judgment Day (1991)
# - Toy Story (1995)
# - Babe (1995)
# - Clueless (1995)
# - Friday (1995)
# - Braveheart (1995)
# - Billy Madison (1995)
# - Forget Paris (1995)
# - Houseguest (1994)
# - Santa Clause, The (1994)
# - While You Were Sleeping (1995)
# - Sense and Sensibility (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Dead Man Walking (1995)
# - Richard III (1995)
# - Postino, Il (The Postman) (1994)
# - Misérables, Les (1995)
# - Braveheart (1995)
# - Apollo 13 (1995)
# - Eat Drink Man Woman (1994)
# - Grumpier Old Men (1995)
# - Sense and Sensibility (1995)
# - Misérables, Les (1995)
# - Bridges of Madison County, The (1995)
# - Like Water for Chocolate (Como agua para chocolate) (1992)
# - Forrest Gump (1994)
# - Piano, The (1993)
# - Schindler's List (1993)
# - Shadowlands (1993)
# - Sleepless in Seattle (1993)
# - Grumpier Old Men (1995)
# - Copycat (1995)
# - Clueless (1995)
# - Two if by Sea (1996)
# - Walk in the Clouds, A (1995)
# - While You Were Sleeping (1995)
# - Richie Rich (1994)
# - Sleepless in Seattle (1993)
# - Silence of the Lambs, The (1991)
# - Snow White and the Seven Dwarfs (1937)
# - American President, The (1995)
# - Sense and Sensibility (1995)
# - Bridges of Madison County, The (1995)
# - Star Wars: Episode IV - A New Hope (1977)
# - Miracle on 34th Street (1994)
# - Forrest Gump (1994)
# - Four Weddings and a Funeral (1994)
# - Dave (1993)
# - Firm, The (1993)
# - Jurassic Park (1993)
#
# Cluster 7 (Clustering Hierárquico):
# - American President, The (1995)
# - Get Shorty (1995)
# - Forrest Gump (1994)
# - Four Weddings and a Funeral (1994)
# - Maverick (1994)
# - Dave (1993)
# - Jurassic Park (1993)
# - Ghost (1990)
# - Mission: Impossible (1996)
# - Philadelphia Story, The (1940)
# - Toy Story (1995)
# - Get Shorty (1995)
# - Babe (1995)
# - Friday (1995)
# - Happy Gilmore (1996)
# - Birdcage, The (1996)
# - Mallrats (1995)
# - Clerks (1994)
# - Stuart Saves His Family (1995)
# - Adventures of Priscilla, Queen of the Desert, The (1994)
# - Grumpier Old Men (1995)
# - Sabrina (1995)
# - American President, The (1995)
# - Leaving Las Vegas (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Dead Man Walking (1995)
# - Dead Presidents (1995)
# - Seven (Se7en) (1995)
# - Usual Suspects, The (1995)
# - Jumanji (1995)
# - American President, The (1995)
# - Powder (1995)
# - Leaving Las Vegas (1995)
# - Othello (1995)
# - Babe (1995)
# - Mr. Holland's Opus (1995)
# - White Squall (1996)
# - Braveheart (1995)
# - Apollo 13 (1995)
# - GoldenEye (1995)
# - Clueless (1995)
# - To Die For (1995)
# - Usual Suspects, The (1995)
# - Happy Gilmore (1996)
# - Apollo 13 (1995)
# - Circle of Friends (1995)
# - Star Wars: Episode IV - A New Hope (1977)
# - Shawshank Redemption, The (1994)
# - What's Eating Gilbert Grape (1993)
# - Toy Story (1995)
# - Get Shorty (1995)
# - Powder (1995)
# - Babe (1995)
# - Clueless (1995)
# - Mighty Aphrodite (1995)
# - Happy Gilmore (1996)
# - Birdcage, The (1996)
# - Mallrats (1995)
# - Clerks (1994)
# - Toy Story (1995)
# - Leaving Las Vegas (1995)
# - Twelve Monkeys (1995)
# - Clueless (1995)
# - Usual Suspects, The (1995)
# - Misérables, Les (1995)
# - Chungking Express (1994)
# - Apollo 13 (1995)
# - Crimson Tide (1995)
# - Eat Drink Man Woman (1994)
# - Mighty Aphrodite (1995)
# - Happy Gilmore (1996)
# - Mallrats (1995)
# - Boys on the Side (1995)
# - Don Juan DeMarco (1995)
# - Dumb & Dumber (1994)
# - Ed Wood (1994)
# - Murder in the First (1995)
# - Adventures of Priscilla, Queen of the Desert, The (1994)
# - Bullets Over Broadway (1994)
# - Toy Story (1995)
# - Powder (1995)
# - Usual Suspects, The (1995)
# - Braveheart (1995)
# - Apollo 13 (1995)
# - Rob Roy (1995)
# - Junior (1994)
# - Star Wars: Episode IV - A New Hope (1977)
# - Legends of the Fall (1994)
# - Pulp Fiction (1994)
# - Father of the Bride Part II (1995)
# - GoldenEye (1995)
# - Get Shorty (1995)
# - Mr. Holland's Opus (1995)
# - Bridges of Madison County, The (1995)
# - Braveheart (1995)
# - Taxi Driver (1976)
# - Apollo 13 (1995)
# - Batman Forever (1995)
# - Dumb & Dumber (1994)
#
# Cluster 8 (Clustering Hierárquico):
# - Heat (1995)
# - Casino (1995)
# - Powder (1995)
# - City of Lost Children, The (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Dead Man Walking (1995)
# - Clueless (1995)
# - Richard III (1995)
# - Seven (Se7en) (1995)
# - Toy Story (1995)
# - Waiting to Exhale (1995)
# - Nixon (1995)
# - Casino (1995)
# - Sense and Sensibility (1995)
# - Powder (1995)
# - Leaving Las Vegas (1995)
# - Dead Man Walking (1995)
# - Clueless (1995)
# - Dead Presidents (1995)
# - Jumanji (1995)
# - Casino (1995)
# - Twelve Monkeys (1995)
# - Richard III (1995)
# - Seven (Se7en) (1995)
# - Usual Suspects, The (1995)
# - Braveheart (1995)
# - Taxi Driver (1976)
# - Rumble in the Bronx (1995)
# - Rob Roy (1995)
# - Heat (1995)
# - Get Shorty (1995)
# - Dead Presidents (1995)
# - Seven (Se7en) (1995)
# - Usual Suspects, The (1995)
# - From Dusk Till Dawn (1996)
# - Things to Do in Denver when You're Dead (1995)
# - Die Hard: With a Vengeance (1995)
# - Strange Days (1995)
# - Ed Wood (1994)
# - Toy Story (1995)
# - Jumanji (1995)
# - GoldenEye (1995)
# - American President, The (1995)
# - Nixon (1995)
# - Casino (1995)
# - Copycat (1995)
# - Twelve Monkeys (1995)
# - Clueless (1995)
# - To Die For (1995)
# - Usual Suspects, The (1995)
# - Taxi Driver (1976)
# - Amateur (1994)
# - Star Wars: Episode IV - A New Hope (1977)
# - Professional, The (a.k.a. Leon: The Professional) (1994)
# - Pulp Fiction (1994)
# - Shawshank Redemption, The (1994)
# - Adventures of Priscilla, Queen of the Desert, The (1994)
# - Schindler's List (1993)
# - Terminator 2: Judgment Day (1991)
# - Toy Story (1995)
# - Jumanji (1995)
# - Sense and Sensibility (1995)
# - Babe (1995)
# - How to Make an American Quilt (1995)
# - Postino, Il (The Postman) (1994)
# - Mr. Holland's Opus (1995)
# - Antonia's Line (Antonia) (1995)
# - Birdcage, The (1996)
# - Apollo 13 (1995)
# - Grumpier Old Men (1995)
# - Heat (1995)
# - Nixon (1995)
# - Casino (1995)
# - Four Rooms (1995)
# - Money Train (1995)
# - Leaving Las Vegas (1995)
# - Twelve Monkeys (1995)
# - Dead Man Walking (1995)
# - Clueless (1995)
# - Get Shorty (1995)
# - Twelve Monkeys (1995)
# - Dead Man Walking (1995)
# - Usual Suspects, The (1995)
# - Taxi Driver (1976)
# - Brothers McMullen, The (1995)
# - Apollo 13 (1995)
# - Burnt By the Sun (Utomlyonnye solntsem) (1994)
# - Like Water for Chocolate (Como agua para chocolate) (1992)
# - Little Odessa (1994)
# - Grumpier Old Men (1995)
# - American President, The (1995)
# - Sense and Sensibility (1995)
# - Copycat (1995)
# - Powder (1995)
# - Leaving Las Vegas (1995)
# - Now and Then (1995)
# - Babe (1995)
# - Clueless (1995)
# - Mr. Holland's Opus (1995)
#
# Cluster 9 (Clustering Hierárquico):
# - Toy Story (1995)
# - Jumanji (1995)
# - Sabrina (1995)
# - Powder (1995)
# - Twelve Monkeys (1995)
# - Pocahontas (1995)
# - Mr. Holland's Opus (1995)
# - Happy Gilmore (1996)
# - Braveheart (1995)
# - Anne Frank Remembered (1995)
# - GoldenEye (1995)
# - Casino (1995)
# - Twelve Monkeys (1995)
# - Clueless (1995)
# - Seven (Se7en) (1995)
# - Bio-Dome (1996)
# - From Dusk Till Dawn (1996)
# - Things to Do in Denver when You're Dead (1995)
# - Broken Arrow (1996)
# - Happy Gilmore (1996)
# - Toy Story (1995)
# - Jumanji (1995)
# - Heat (1995)
# - American President, The (1995)
# - Casino (1995)
# - Get Shorty (1995)
# - City of Lost Children, The (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Clueless (1995)
# - Toy Story (1995)
# - Heat (1995)
# - Sabrina (1995)
# - GoldenEye (1995)
# - American President, The (1995)
# - Casino (1995)
# - Get Shorty (1995)
# - Shanghai Triad (Yao a yao yao dao waipo qiao) (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Toy Story (1995)
# - Grumpier Old Men (1995)
# - Sabrina (1995)
# - American President, The (1995)
# - Leaving Las Vegas (1995)
# - Babe (1995)
# - Carrington (1995)
# - Clueless (1995)
# - How to Make an American Quilt (1995)
# - Pocahontas (1995)
# - Toy Story (1995)
# - Jumanji (1995)
# - Father of the Bride Part II (1995)
# - Heat (1995)
# - Sabrina (1995)
# - GoldenEye (1995)
# - Cutthroat Island (1995)
# - Sense and Sensibility (1995)
# - Ace Ventura: When Nature Calls (1995)
# - Get Shorty (1995)
# - Jumanji (1995)
# - Casino (1995)
# - Sense and Sensibility (1995)
# - Four Rooms (1995)
# - Get Shorty (1995)
# - Copycat (1995)
# - Leaving Las Vegas (1995)
# - City of Lost Children, The (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Toy Story (1995)
# - Jumanji (1995)
# - Heat (1995)
# - Tom and Huck (1995)
# - Sense and Sensibility (1995)
# - Powder (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Dead Man Walking (1995)
# - Clueless (1995)
# - Toy Story (1995)
# - Jumanji (1995)
# - Sabrina (1995)
# - GoldenEye (1995)
# - American President, The (1995)
# - Cutthroat Island (1995)
# - Sense and Sensibility (1995)
# - Assassins (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Toy Story (1995)
# - Jumanji (1995)
# - Heat (1995)
# - Sudden Death (1995)
# - GoldenEye (1995)
# - Casino (1995)
# - Sense and Sensibility (1995)
# - Get Shorty (1995)
# - Copycat (1995)
# - Powder (1995)

# %%
# Interpretar clusters do DBSCAN
dbscan = DBSCAN(metric='cosine', eps=0.3, min_samples=10)
dbscan_clusters = dbscan.fit_predict(user_movie_matrix_normalized)

# Exibir clusters do DBSCAN
unique_dbscan_clusters = np.unique(dbscan_clusters)
print(f'\nInterpretação dos clusters do DBSCAN:')
for cluster in unique_dbscan_clusters:
    if cluster == -1:
        print(f'\nOutliers:')
    else:
        print(f'\nCluster {cluster}:')
    cluster_indices = np.where(dbscan_clusters == cluster)[0]
    for index in cluster_indices[:10]:  # Mostrar os 10 primeiros usuários no cluster
        rated_movie_indices = np.where(user_movie_matrix.iloc[index, :] > 0)[0]
        rated_movies = [user_movie_matrix.columns[i] for i in rated_movie_indices]
        movie_titles_in_cluster = [movie_titles[movie_id] for movie_id in rated_movies[:10]]
        for movie_title in movie_titles_in_cluster:
            print(f"- {movie_title}")
# Out:
# Interpretação dos clusters do DBSCAN:
#
# Outliers:
# - Toy Story (1995)
# - Pocahontas (1995)
# - Apollo 13 (1995)
# - Star Wars: Episode IV - A New Hope (1977)
# - Schindler's List (1993)
# - Secret Garden, The (1993)
# - Aladdin (1992)
# - Snow White and the Seven Dwarfs (1937)
# - Beauty and the Beast (1991)
# - Fargo (1996)
# - Get Shorty (1995)
# - Broken Arrow (1996)
# - Braveheart (1995)
# - Desperado (1995)
# - Die Hard: With a Vengeance (1995)
# - Ed Wood (1994)
# - Like Water for Chocolate (Como agua para chocolate) (1992)
# - Outbreak (1995)
# - Shawshank Redemption, The (1994)
# - Clear and Present Danger (1994)
# - Happy Gilmore (1996)
# - Star Wars: Episode IV - A New Hope (1977)
# - Jurassic Park (1993)
# - Three Musketeers, The (1993)
# - Dances with Wolves (1990)
# - Silence of the Lambs, The (1991)
# - Mission: Impossible (1996)
# - Dragonheart (1996)
# - Rock, The (1996)
# - Ghost and the Darkness, The (1996)
# - Star Wars: Episode IV - A New Hope (1977)
# - Jurassic Park (1993)
# - Die Hard (1988)
# - E.T. the Extra-Terrestrial (1982)
# - Star Wars: Episode V - The Empire Strikes Back (1980)
# - Raiders of the Lost Ark (1981)
# - Good, The Bad and The Ugly, The (1966)
# - Star Wars: Episode VI - Return of the Jedi (1983)
# - Alien (1979)
# - Terminator, The (1984)
# - Heat (1995)
# - Casino (1995)
# - Powder (1995)
# - City of Lost Children, The (1995)
# - Twelve Monkeys (1995)
# - Babe (1995)
# - Dead Man Walking (1995)
# - Clueless (1995)
# - Richard III (1995)
# - Seven (Se7en) (1995)
# - Toy Story (1995)
# - Sense and Sensibility (1995)
# - Babe (1995)
# - Pocahontas (1995)
# - Umbrellas of Cherbourg, The (Parapluies de Cherbourg, Les) (1964)
# - Legends of the Fall (1994)
# - Pulp Fiction (1994)
# - Lion King, The (1994)
# - Maverick (1994)
# - Speed (1994)
# - Heat (1995)
# - Braveheart (1995)
# - Clear and Present Danger (1994)
# - Speed (1994)
# - True Lies (1994)
# - Demolition Man (1993)
# - Fugitive, The (1993)
# - In the Line of Fire (1993)
# - Jurassic Park (1993)
# - Terminator 2: Judgment Day (1991)
# - Toy Story (1995)
# - Waiting to Exhale (1995)
# - Nixon (1995)
# - Casino (1995)
# - Sense and Sensibility (1995)
# - Powder (1995)
# - Leaving Las Vegas (1995)
# - Dead Man Walking (1995)
# - Clueless (1995)
# - Dead Presidents (1995)
# - Toy Story (1995)
# - Casino (1995)
# - Leaving Las Vegas (1995)
# - Seven (Se7en) (1995)
# - Usual Suspects, The (1995)
# - Apollo 13 (1995)
# - Crumb (1994)
# - Clerks (1994)
# - Quiz Show (1994)
# - Shawshank Redemption, The (1994)
# - Toy Story (1995)
# - Jumanji (1995)
# - Sabrina (1995)
# - Powder (1995)
# - Twelve Monkeys (1995)
# - Pocahontas (1995)
# - Mr. Holland's Opus (1995)
# - Happy Gilmore (1996)
# - Braveheart (1995)
# - Anne Frank Remembered (1995)

# %% [markdown]
# ## Conclusão
#
# Neste trabalho, realizamos uma análise exploratória dos dados do MovieLens 1M, verificando a quantidade de filmes, usuários e avaliações, e visualizando a distribuição das avaliações, gêneros e quantidade de filmes por ano. Em seguida, pré-processamos os dados e calculamos a matriz de distâncias.
#
# Aplicamos três algoritmos de clusterização (K-means, DBSCAN e clustering hierárquico) e analisamos a variação do número de clusters. Também removemos outliers e aplicamos redução de dimensionalidade utilizando PCA e SVD.
#
# Finalmente, interpretamos os clusters obtidos com o algoritmo K-means, identificando grupos de filmes semelhantes.
#
# Durante o processo, encontramos alguns desafios, como a necessidade de normalização dos dados e a escolha do número adequado de clusters. Possíveis melhorias futuras incluem a aplicação de outros algoritmos de clusterização e a consideração de mais informações dos filmes e usuários.
#
# Os principais achados foram a identificação de grupos de filmes com características semelhantes, que podem ser usados para recomendações personalizadas. A redução de dimensionalidade ajudou a visualizar a distribuição dos dados e a identificar padrões nos clusters.
#
# Em conclusão, a análise realizada forneceu insights valiosos sobre o conjunto de dados MovieLens 1M e demonstrou a eficácia dos algoritmos de clusterização na segmentação de dados complexos.
